# %% [markdown]
# ##EXPLORING AUDIO ONSET DETECTION WITH MACHINE LEARNING
#
# This  work  aims  to  further  explore  the  task  of  Audio  Onset Detection with deep learning, presenting a novel Convolutional  Recurrent  Neural  Network  CRNN  for  Musical Onset  Detection.  In  particular, the proposed  architecture has been trained with different hyper-parameter tuning and CNN kernel filters size in order to find the best combination of parameters in terms of performances. Two different dataset have been used for the scope of the project, *Leveau* dataset [1] and the merge of it with *Holzapfel* dataset [2].The model has also been trained with two different input, **spectrogram**  and  **log-normalized  Mel  Band  spectrogram**.
#
# [1]: http://www.tsi.telecom-paristech.fr/aao/en/2011/07/13/onset_leveau-a-database-for-onset-detection/
# [2]: Holzapfel, André, et al. "Three dimensions of pitched instrument onset detection." IEEE Transactions on Audio, Speech, and Language Processing 18.6 (2009): 1517-1527.

# %% [markdown]
# ## DATASET USED IN THIS NOTEBOOK
#
# This notebook presents the CRNN network and the dataset used considering the case of **Leveu + Holzapfel** dataset and **log-normalized Mel Band spectrogram** input. Mel Band considered: 32
#
# Please, go through the notebook carefully to change paths according to your own directories.
#
# The notebook is divided in two sections:
# - Extraction of features (32 Mel Bands spectrogram)
# - CRNN:
#   - Squared Neural Network (kernel filter size: 3X3)
#   - High Neural Network (kernel filter size: 2x6)
#   - Wide Neural Network (kernel filter size: 6x2)

# %% [markdown]
# ## Extraction of features
#
# The following instructions will extract the 32 Mel Bands from the spectrogram and the label which we will used for training and testing the CRNN networks as ground truth.

# %% [markdown]
# First, lets make sure we are using Tensorflow 2.0 and we have a GPU available.

# %%
#script to process data from prof dataset 
# %tensorflow_version 2.x

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.2.0-rc2

# %%
# !pip install essentia
# Out:
# Requirement already satisfied: essentia in /usr/local/lib/python3.6/dist-packages (2.1b6.dev184)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from essentia) (1.18.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from essentia) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from essentia) (1.12.0)

# %%
#mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#lets define all the module and paths we will need
import os
import numpy as np
import scipy.io.wavfile as wav
from sklearn import preprocessing
from sklearn.externals import joblib
from numpy import genfromtxt
import matplotlib.pyplot as plt 
from essentia.standard import *
from scipy import signal
import essentia

#dataset base folder path
dataset_folder = os.path.join('drive/My Drive/dataset_MIR/final_dataset_try/')
#audio file fodler path
wav_path = dataset_folder + 'wav_files/'
#log mel spectrogram folder path 
spect_path = dataset_folder + 'log_mel_spectogram/'
#spectrogram normalized folder path (the normalized spectrogram will be saved inside this folder)
norm_folder_path = dataset_folder + 'log_mel_spectogram_norm/'
#file for weight normalization 
normalized_features_wts_file = dataset_folder  + 'logmel_spect_wts'
#label folder path (the label extracted will be saved inside this folder)
label_path = dataset_folder + 'labels/'
#txt label file folder path 
txt_path = dataset_folder + 'txt_files/'

# %%
eps = np.spacing(np.float(1e-16))
#window length
win_len = 512
#hop size length
hop_len = 256
#FFT 
nfft = 512
#sample rate
fs = 44100
#max length considered for the audio file
aud_max_len_samples = 15 * fs  # longest file 20 seconds not considering all the files longer than 20 seconds
#max number of frames
max_frames = int(np.ceil((aud_max_len_samples - win_len) / float(hop_len)))
#max number of frames
print("Max number of frames in a file: {}".format(max_frames))
#frame resolution
frame_res = fs / float(hop_len)
# Out:
# Max number of frames in a file: 2582

# %% [markdown]
# Lets define all the functions we will need for the extraction of the log normalized Mel Band spectrogram.

# %%
#function to create folder
def create_folder(folder_name):
    '''
    The function create a folder (if it already does not exist) with the name specified as input parameter into the current path
    Parameters:
    -----------
        :folder_name: name of the folder
    '''
    if not os.path.exists(folder_name):
        print('{} folder does not exist, creating it.'.format(folder_name))
        os.makedirs(folder_name)

# %%
def load_audio(audio_path):
    '''
    The function _load_audio loads an audio file into an array.
    If the exceeds the length of maximum samples, it get re-size to the maximum samples length,
    otherwise it is zero padded.
    Parameters:
    ------------
        :audio_path: the path where the file is saved
    Returns:
    ----------
        :tuple containing array of audio sampled (audio) and sampling frequency (fs)
    '''
    audio = loader = essentia.standard.MonoLoader(filename=audio_path)

    audio = loader()
    audio = audio / 32768.0 + eps  # maxim integer and bit coding
    #print('after', audio)
    audio = audio.reshape(audio.shape[0], 1)
    if audio.shape[0] < aud_max_len_samples:
         zero_pad = np.zeros((aud_max_len_samples - audio.shape[0], audio.shape[1]))
         audio = np.vstack((audio, zero_pad))
    elif audio.shape[0] > aud_max_len_samples:
         audio = audio[:aud_max_len_samples, :]
    return audio

# %%
def mel_spectrogram(audio_in):
    '''
    The function extracts the spectrogram of the audio file given as input parameter
    Parameters:
    -----------
    :audio_in: audio samples
    '''
    w = Windowing(type = 'hann')
    spectrum = Spectrum()  # FFT() would return the complex FFT, here we just want the magnitude spectrum
    mfcc = MFCC(numberBands = 32)
    logNorm = UnaryOperator(type='log')


    mfccs = []
    melbands = []
    melbands_log = []

    for frame in FrameGenerator(audio_in[:,0], frameSize=win_len, hopSize=hop_len, startFromZero=True):
      mfcc_bands, mfcc_coeffs = mfcc(spectrum(w(frame)))
      mfccs.append(mfcc_coeffs)
      melbands.append(mfcc_bands)
      melbands_log.append(logNorm(mfcc_bands))

    melbands_log = melbands_log[:max_frames]  
    print(len(melbands_log))

      # transpose to have it in a better shape
      # we need to convert the list to an essentia.array first (== numpy.array of floats)

    mfccs = essentia.array(mfccs).T   
    melbands = essentia.array(melbands).T
    melbands_log = essentia.array(melbands_log).T


    imshow(melbands_log[:,:], aspect = 'auto', origin='lower', interpolation='none')
    plt.title("Log-normalized mel band spectral energies in frames")
    show()

    print("Log_normalize mel band spectral energies in frames: ", melbands_log.shape)

    return melbands_log.T

# %%
def extract_mel_spectogram(audio_filename, file, file_count, spect_path):
    '''
    The function handle the extraction of the spectrogram of the input file and save in in the feature directory
    Parameters:
    -----------
        :audio_filename: the name of the file for which the spectrogram is extracted
    '''

    audio_in = load_audio(audio_filename)

    spec = mel_spectrogram(audio_in)

    file_name = audio_filename.split('/')[-1]
    path = spect_path + file_name
    print("Saving file {0} with shape {1}".format(audio_filename, spec.shape))
    np.save(path, spec)
    print("Saving file {0} with shape {1}".format(audio_filename, spec.shape))
    print("Log-spectogram file {0} saved in {1}".format(audio_filename, path))
    

    return spec

# %%
#function to nornalize the features
def normalize_feature(spect_path, normalized_features_wts_file, norm_folder_path):

    spec_scaler = preprocessing.StandardScaler()
    train_cnt = 0

    for file_cnt, file_name in enumerate(os.listdir(spect_path)):
        if 'training_' in file_name and file_name != '.DS_Store':
            print(file_cnt, train_cnt, file_name)
            feat_file = np.load(os.path.join(spect_path, file_name))
            spec_scaler.partial_fit(feat_file)
            del feat_file
            train_cnt += 1
            # check point, saving the feature scaling (normalization) to a file on a disk

    joblib.dump(
        spec_scaler,
        normalized_features_wts_file
    )
    print("Weighthed count on {} training file".format(train_cnt))

    print('Normalizing feature files')
    for file_cnt, file_name in enumerate(os.listdir(spect_path)):
        if file_name != '.DS_Store':
            print(file_cnt, file_name)
            feat_file = np.load(os.path.join(spect_path, file_name))
            feat_file = spec_scaler.transform(feat_file)
            print("Feature file shape: {}".format(feat_file.shape))
            np.save(
                os.path.join(norm_folder_path, file_name),
                feat_file
            )
            del feat_file

    print('normalized files written to {} folder and the scaler to {}'.format(
        norm_folder_path, normalized_features_wts_file))

    print("Normalized {} files ".format(file_cnt))

# %%
#function to read txt file and extract the labels
def read_desc_file(file_name):
  '''
  The function extract the label from the csv file and save them inside the array labels.
  Parameters:
  ---------------
  Input:
  :file_name: the path of the file where to extract thr label from
  Output
  :labels: label array to return
  '''
  labels = genfromtxt(file_name, delimiter=',')
  return labels

# %%
#function to extract the label from file and save them inside the se_label. 
def get_labels_for_file(desc_file):
  '''
  The function saved all the label inside the array se_label. 
  For each label extracted from the desc_file, it is calculated the frame where the onset is active and saved as 1 in the array se_label. 
  Input paramaters:
  ----------------------
  :desc_file: label file for the audio file considered
  Return:
  -----------
  se_label: array describing the audio file where 1 means onset present on the frame and 0 means no audio onset present in the audio file
  '''
  onset_array = []
  se_label = np.zeros(max_frames)
  for i in range(len(desc_file)):
    onset_frame = int(np.floor(float(desc_file[i]) * frame_res))
    if onset_frame < max_frames:
      onset_array.append(onset_frame)
      se_label[onset_frame] = 1

  return se_label

# %% [markdown]
# Now, lets have a look at the list of file we are going to use in this notebook.

# %%
#@title
file_count = 0
print("File that will be processed: ")
for file in os.listdir(wav_path):
    if not file.startswith('.'):
        print(file)
        file_count += 1

print("Total number of file in dataset: {}".format(file_count))
# Out:
# File that will be processed:
# training_DiverseTaksim_pt1.wav
# training_SummerTogether.wav
# training_kemence_08.wav
# training_Guitar_Licks_06-11.wav
# training_tabla.wav
# training_Cello_Suite_Preludium.wav
# test_mixtures_rock1.wav
# training_oud_1.wav
# training_Guitar_Licks_51-10.wav
# training_violin_hoochie.wav
# test_ne_se04.wav
# training_trumpet_02.wav
# training_sax_george.wav
# training_ne_icm13.wav
# training_piano_mussorgsky.wav
# training_Guitar_Licks_06-12.wav
# training_Jaillet64.wav
# test_tambourine.wav
# training_piano_autumn.wav
# training_piano_02.wav
# test_ta_1mc08.wav
# training_violin2.wav
# test_piano_p5.wav
# training_ta_1eb08.wav
# training_celloTaksim_pt1.wav
# training_trumpet4.wav
# training_bongo1.wav
# training_ta_1eb03.wav
# training_piano_08.wav
# training_piano_p3.wav
# training_violin3.wav
# training_trumpet_chetbaker.wav
# test_triangle.wav
# training_Guitar_Licks_07-11.wav
# training_ud_06.wav
# training_clarinet1.wav
# training_ud_03.wav
# test_oud_taksimleri_pt1.wav
# training_violin1.wav
# training_Guitar_Licks_15-05.wav
# training_sax_stephenchai.wav
# test_ud_17.wav
# test_TexasMusicForge.wav
# training_kemence_01.wav
# test_violin_dark_eyes_viol.wav
# training_guitar1.wav
# training_conga1.wav
# training_mixtures_jazz3.wav
# training_Guitar_Licks_07-06.wav
# training_ne_icm05.wav
# training_castagnet1.wav
# training_oud_rast_taksim1.wav
# training_ta_1eb06.wav
# training_piano_corea_08.wav
# training_sax_12.wav
# training_Guitar_Licks_15-06.wav
# test_trumpet33.wav
# training_Cello_Sonata_3_pt1.wav
# training_kemence_11.wav
# training_oud_8.wav
# training_kamence_10.wav
# test_CelloTaksimi_pt1.wav
# training_clarinet_SL1_pt1.wav
# test_ne_tmu2n06.wav
# training_piano_corea_03.wav
# training_cello1.wav
# training_piano_full.wav
# training_ud_04.wav
# training_violin_03__kurdilihicazkar__keman.wav
# training_mixtures_classic2.wav
# training_trumpet1.wav
# training_ud_02.wav
# training_mixtures_classic3.wav
# training_ne_icm09.wav
# training_ne_se01.wav
# training_ne_se03.wav
# training_guitar3.wav
# training_ta_1eb07.wav
# training_guitar2.wav
# training_mixtures_jazz2.wav
# test_violin4.wav
# training_clarinet_44784_pt1.wav
# training_sax_06.wav
# test_piano1.wav
# test_sax1.wav
# training_violin_01_hicaz.wav
# test_kemence_22.wav
# training_clarinet_44361.wav
# training_piano_MOON.wav
# test_mixtures_pop1.wav
# training_techno2.wav
# test_jazz3.wav
# training_synthbass1.wav
# training_distguit1.wav
# training_leveau_techno2.wav
# test_leveau_jazz3.wav
# test_leveau_classic3.wav
# training_leveau_synthbass1.wav
# training_leveau_distguit1.wav
# test_leveau_guitar3.wav
# training_leveau_cello1.wav
# training_leveau_classic2.wav
# training_leveau_guitar2.wav
# training_leveau_jazz2.wav
# training_leveau_piano1.wav
# training_leveau_pop1.wav
# training_leveau_sax1.wav
# training_leveau_trumpet1.wav
# training_leveau_violin2.wav
# training_leveau_rock1.wav
# Total number of file in dataset: 110

# %%
from pylab import plot, show, figure, imshow
# %matplotlib inline
import matplotlib.pyplot as pl

file_count = 0
#the dataset will be divided anyway in 12 files which will be served for training set and 4 which will be used as test set.
create_folder(spect_path)
create_folder(norm_folder_path)
create_folder(label_path)

#extracting spectogram for each file
for filename in os.listdir(wav_path):
    if not filename.startswith('.'):
      file_path = os.path.join(wav_path, filename)
      extract_mel_spectogram(file_path, filename, file_count, spect_path)

      file_count += 1

print("File processed: {}".format(file_count))
# Out:
# drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/ folder does not exist, creating it.
# drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram_norm/ folder does not exist, creating it.
# drive/My Drive/dataset_MIR/final_dataset_try/labels_log_mel/ folder does not exist, creating it.
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_DiverseTaksim_pt1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_DiverseTaksim_pt1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_DiverseTaksim_pt1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_DiverseTaksim_pt1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_SummerTogether.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_SummerTogether.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_SummerTogether.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_SummerTogether.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_kemence_08.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_kemence_08.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_kemence_08.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_kemence_08.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_06-11.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_06-11.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_06-11.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_Guitar_Licks_06-11.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_tabla.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_tabla.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_tabla.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_tabla.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Cello_Suite_Preludium.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Cello_Suite_Preludium.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Cello_Suite_Preludium.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_Cello_Suite_Preludium.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_mixtures_rock1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_mixtures_rock1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_mixtures_rock1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_mixtures_rock1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_oud_1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_oud_1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_oud_1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_oud_1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_51-10.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_51-10.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_51-10.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_Guitar_Licks_51-10.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin_hoochie.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin_hoochie.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin_hoochie.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_violin_hoochie.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_ne_se04.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_ne_se04.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_ne_se04.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_ne_se04.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_trumpet_02.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_trumpet_02.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_trumpet_02.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_trumpet_02.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_sax_george.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_sax_george.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_sax_george.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_sax_george.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_icm13.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_icm13.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_icm13.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_ne_icm13.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_mussorgsky.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_mussorgsky.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_mussorgsky.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_piano_mussorgsky.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_06-12.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_06-12.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_06-12.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_Guitar_Licks_06-12.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Jaillet64.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Jaillet64.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Jaillet64.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_Jaillet64.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_tambourine.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_tambourine.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_tambourine.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_tambourine.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_autumn.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_autumn.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_autumn.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_piano_autumn.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_02.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_02.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_02.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_piano_02.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_ta_1mc08.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_ta_1mc08.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_ta_1mc08.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_ta_1mc08.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin2.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin2.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin2.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_violin2.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_piano_p5.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_piano_p5.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_piano_p5.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_piano_p5.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ta_1eb08.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ta_1eb08.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ta_1eb08.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_ta_1eb08.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_celloTaksim_pt1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_celloTaksim_pt1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_celloTaksim_pt1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_celloTaksim_pt1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_trumpet4.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_trumpet4.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_trumpet4.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_trumpet4.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_bongo1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_bongo1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_bongo1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_bongo1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ta_1eb03.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ta_1eb03.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ta_1eb03.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_ta_1eb03.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_08.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_08.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_08.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_piano_08.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_p3.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_p3.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_p3.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_piano_p3.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin3.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin3.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin3.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_violin3.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_trumpet_chetbaker.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_trumpet_chetbaker.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_trumpet_chetbaker.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_trumpet_chetbaker.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_triangle.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_triangle.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_triangle.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_triangle.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_07-11.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_07-11.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_07-11.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_Guitar_Licks_07-11.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ud_06.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ud_06.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ud_06.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_ud_06.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_clarinet1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_clarinet1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_clarinet1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_clarinet1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ud_03.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ud_03.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ud_03.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_ud_03.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_oud_taksimleri_pt1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_oud_taksimleri_pt1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_oud_taksimleri_pt1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_oud_taksimleri_pt1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_violin1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_15-05.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_15-05.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_15-05.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_Guitar_Licks_15-05.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_sax_stephenchai.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_sax_stephenchai.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_sax_stephenchai.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_sax_stephenchai.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_ud_17.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_ud_17.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_ud_17.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_ud_17.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_TexasMusicForge.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_TexasMusicForge.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_TexasMusicForge.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_TexasMusicForge.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_kemence_01.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_kemence_01.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_kemence_01.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_kemence_01.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_violin_dark_eyes_viol.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_violin_dark_eyes_viol.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_violin_dark_eyes_viol.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_violin_dark_eyes_viol.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_guitar1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_guitar1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_guitar1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_guitar1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_conga1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_conga1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_conga1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_conga1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_mixtures_jazz3.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_mixtures_jazz3.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_mixtures_jazz3.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_mixtures_jazz3.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_07-06.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_07-06.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_07-06.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_Guitar_Licks_07-06.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_icm05.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_icm05.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_icm05.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_ne_icm05.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_castagnet1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_castagnet1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_castagnet1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_castagnet1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_oud_rast_taksim1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_oud_rast_taksim1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_oud_rast_taksim1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_oud_rast_taksim1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ta_1eb06.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ta_1eb06.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ta_1eb06.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_ta_1eb06.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_corea_08.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_corea_08.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_corea_08.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_piano_corea_08.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_sax_12.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_sax_12.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_sax_12.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_sax_12.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_15-06.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_15-06.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Guitar_Licks_15-06.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_Guitar_Licks_15-06.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_trumpet33.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_trumpet33.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_trumpet33.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_trumpet33.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Cello_Sonata_3_pt1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Cello_Sonata_3_pt1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_Cello_Sonata_3_pt1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_Cello_Sonata_3_pt1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_kemence_11.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_kemence_11.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_kemence_11.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_kemence_11.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_oud_8.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_oud_8.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_oud_8.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_oud_8.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_kamence_10.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_kamence_10.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_kamence_10.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_kamence_10.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_CelloTaksimi_pt1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_CelloTaksimi_pt1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_CelloTaksimi_pt1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_CelloTaksimi_pt1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_clarinet_SL1_pt1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_clarinet_SL1_pt1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_clarinet_SL1_pt1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_clarinet_SL1_pt1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_ne_tmu2n06.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_ne_tmu2n06.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_ne_tmu2n06.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_ne_tmu2n06.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_corea_03.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_corea_03.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_corea_03.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_piano_corea_03.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_cello1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_cello1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_cello1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_cello1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_full.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_full.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_full.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_piano_full.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ud_04.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ud_04.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ud_04.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_ud_04.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin_03__kurdilihicazkar__keman.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin_03__kurdilihicazkar__keman.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin_03__kurdilihicazkar__keman.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_violin_03__kurdilihicazkar__keman.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_mixtures_classic2.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_mixtures_classic2.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_mixtures_classic2.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_mixtures_classic2.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_trumpet1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_trumpet1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_trumpet1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_trumpet1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ud_02.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ud_02.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ud_02.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_ud_02.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_mixtures_classic3.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_mixtures_classic3.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_mixtures_classic3.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_mixtures_classic3.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_icm09.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_icm09.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_icm09.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_ne_icm09.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_se01.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_se01.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_se01.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_ne_se01.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_se03.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_se03.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ne_se03.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_ne_se03.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_guitar3.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_guitar3.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_guitar3.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_guitar3.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ta_1eb07.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ta_1eb07.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_ta_1eb07.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_ta_1eb07.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_guitar2.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_guitar2.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_guitar2.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_guitar2.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_mixtures_jazz2.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_mixtures_jazz2.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_mixtures_jazz2.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_mixtures_jazz2.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_violin4.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_violin4.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_violin4.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_violin4.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_clarinet_44784_pt1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_clarinet_44784_pt1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_clarinet_44784_pt1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_clarinet_44784_pt1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_sax_06.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_sax_06.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_sax_06.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_sax_06.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_piano1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_piano1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_piano1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_piano1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_sax1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_sax1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_sax1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_sax1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin_01_hicaz.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin_01_hicaz.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_violin_01_hicaz.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_violin_01_hicaz.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_kemence_22.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_kemence_22.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_kemence_22.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_kemence_22.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_clarinet_44361.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_clarinet_44361.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_clarinet_44361.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_clarinet_44361.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_MOON.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_MOON.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_piano_MOON.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_piano_MOON.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_mixtures_pop1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_mixtures_pop1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_mixtures_pop1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_mixtures_pop1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_techno2.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_techno2.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_techno2.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_techno2.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_jazz3.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_jazz3.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_jazz3.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_jazz3.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_synthbass1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_synthbass1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_synthbass1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_synthbass1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_distguit1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_distguit1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_distguit1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_distguit1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_techno2.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_techno2.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_techno2.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_leveau_techno2.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_leveau_jazz3.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_leveau_jazz3.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_leveau_jazz3.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_leveau_jazz3.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_leveau_classic3.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_leveau_classic3.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_leveau_classic3.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_leveau_classic3.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_synthbass1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_synthbass1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_synthbass1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_leveau_synthbass1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_distguit1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_distguit1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_distguit1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_leveau_distguit1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_leveau_guitar3.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_leveau_guitar3.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/test_leveau_guitar3.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/test_leveau_guitar3.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_cello1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_cello1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_cello1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_leveau_cello1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_classic2.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_classic2.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_classic2.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_leveau_classic2.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_guitar2.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_guitar2.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_guitar2.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_leveau_guitar2.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_jazz2.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_jazz2.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_jazz2.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_leveau_jazz2.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_piano1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_piano1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_piano1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_leveau_piano1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_pop1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_pop1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_pop1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_leveau_pop1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_sax1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_sax1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_sax1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_leveau_sax1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_trumpet1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_trumpet1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_trumpet1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_leveau_trumpet1.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_violin2.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_violin2.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_violin2.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_leveau_violin2.wav
# 2582
# Log_normalize mel band spectral energies in frames:  (32, 2582)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_rock1.wav with shape (2582, 32)
# Saving file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_rock1.wav with shape (2582, 32)
# Log-spectogram file drive/My Drive/dataset_MIR/final_dataset_try/wav_files/training_leveau_rock1.wav saved in drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram/training_leveau_rock1.wav
# File processed: 110

# %%
#normalizing feature for each filecf
normalize_feature(spect_path, normalized_features_wts_file, norm_folder_path)
# Out:
# 0 0 training_DiverseTaksim_pt1.wav.npy
# 1 1 training_SummerTogether.wav.npy
# 2 2 training_kemence_08.wav.npy
# 3 3 training_Guitar_Licks_06-11.wav.npy
# 4 4 training_tabla.wav.npy
# 5 5 training_Cello_Suite_Preludium.wav.npy
# 7 6 training_oud_1.wav.npy
# 8 7 training_Guitar_Licks_51-10.wav.npy
# 9 8 training_violin_hoochie.wav.npy
# 11 9 training_trumpet_02.wav.npy
# 12 10 training_sax_george.wav.npy
# 13 11 training_ne_icm13.wav.npy
# 14 12 training_piano_mussorgsky.wav.npy
# 15 13 training_Guitar_Licks_06-12.wav.npy
# 16 14 training_Jaillet64.wav.npy
# 18 15 training_piano_autumn.wav.npy
# 19 16 training_piano_02.wav.npy
# 21 17 training_violin2.wav.npy
# 23 18 training_ta_1eb08.wav.npy
# 24 19 training_celloTaksim_pt1.wav.npy
# 25 20 training_trumpet4.wav.npy
# 26 21 training_bongo1.wav.npy
# 27 22 training_ta_1eb03.wav.npy
# 28 23 training_piano_08.wav.npy
# 29 24 training_piano_p3.wav.npy
# 30 25 training_violin3.wav.npy
# 31 26 training_trumpet_chetbaker.wav.npy
# 33 27 training_Guitar_Licks_07-11.wav.npy
# 34 28 training_ud_06.wav.npy
# 35 29 training_clarinet1.wav.npy
# 36 30 training_ud_03.wav.npy
# 38 31 training_violin1.wav.npy
# 39 32 training_Guitar_Licks_15-05.wav.npy
# 40 33 training_sax_stephenchai.wav.npy
# 43 34 training_kemence_01.wav.npy
# 45 35 training_guitar1.wav.npy
# 46 36 training_conga1.wav.npy
# 47 37 training_mixtures_jazz3.wav.npy
# 48 38 training_Guitar_Licks_07-06.wav.npy
# 49 39 training_ne_icm05.wav.npy
# 50 40 training_castagnet1.wav.npy
# 51 41 training_oud_rast_taksim1.wav.npy
# 52 42 training_ta_1eb06.wav.npy
# 53 43 training_piano_corea_08.wav.npy
# 54 44 training_sax_12.wav.npy
# 55 45 training_Guitar_Licks_15-06.wav.npy
# 57 46 training_Cello_Sonata_3_pt1.wav.npy
# 58 47 training_kemence_11.wav.npy
# 59 48 training_oud_8.wav.npy
# 60 49 training_kamence_10.wav.npy
# 62 50 training_clarinet_SL1_pt1.wav.npy
# 64 51 training_piano_corea_03.wav.npy
# 65 52 training_cello1.wav.npy
# 66 53 training_piano_full.wav.npy
# 67 54 training_ud_04.wav.npy
# 68 55 training_violin_03__kurdilihicazkar__keman.wav.npy
# 69 56 training_mixtures_classic2.wav.npy
# 70 57 training_trumpet1.wav.npy
# 71 58 training_ud_02.wav.npy
# 72 59 training_mixtures_classic3.wav.npy
# 73 60 training_ne_icm09.wav.npy
# 74 61 training_ne_se01.wav.npy
# 75 62 training_ne_se03.wav.npy
# 76 63 training_guitar3.wav.npy
# 77 64 training_ta_1eb07.wav.npy
# 78 65 training_guitar2.wav.npy
# 79 66 training_mixtures_jazz2.wav.npy
# 81 67 training_clarinet_44784_pt1.wav.npy
# 82 68 training_sax_06.wav.npy
# 85 69 training_violin_01_hicaz.wav.npy
# 87 70 training_clarinet_44361.wav.npy
# 88 71 training_piano_MOON.wav.npy
# 90 72 training_techno2.wav.npy
# 92 73 training_synthbass1.wav.npy
# 93 74 training_distguit1.wav.npy
# 94 75 training_leveau_techno2.wav.npy
# 97 76 training_leveau_synthbass1.wav.npy
# 98 77 training_leveau_distguit1.wav.npy
# 100 78 training_leveau_cello1.wav.npy
# 101 79 training_leveau_classic2.wav.npy
# 102 80 training_leveau_guitar2.wav.npy
# 103 81 training_leveau_jazz2.wav.npy
# 104 82 training_leveau_piano1.wav.npy
# 105 83 training_leveau_pop1.wav.npy
# 106 84 training_leveau_sax1.wav.npy
# 107 85 training_leveau_trumpet1.wav.npy
# 108 86 training_leveau_violin2.wav.npy
# 109 87 training_leveau_rock1.wav.npy
# Weighthed count on 88 training file
# Normalizing feature files
# 0 training_DiverseTaksim_pt1.wav.npy
# Feature file shape: (2582, 32)
# 1 training_SummerTogether.wav.npy
# Feature file shape: (2582, 32)
# 2 training_kemence_08.wav.npy
# Feature file shape: (2582, 32)
# 3 training_Guitar_Licks_06-11.wav.npy
# Feature file shape: (2582, 32)
# 4 training_tabla.wav.npy
# Feature file shape: (2582, 32)
# 5 training_Cello_Suite_Preludium.wav.npy
# Feature file shape: (2582, 32)
# 6 test_mixtures_rock1.wav.npy
# Feature file shape: (2582, 32)
# 7 training_oud_1.wav.npy
# Feature file shape: (2582, 32)
# 8 training_Guitar_Licks_51-10.wav.npy
# Feature file shape: (2582, 32)
# 9 training_violin_hoochie.wav.npy
# Feature file shape: (2582, 32)
# 10 test_ne_se04.wav.npy
# Feature file shape: (2582, 32)
# 11 training_trumpet_02.wav.npy
# Feature file shape: (2582, 32)
# 12 training_sax_george.wav.npy
# Feature file shape: (2582, 32)
# 13 training_ne_icm13.wav.npy
# Feature file shape: (2582, 32)
# 14 training_piano_mussorgsky.wav.npy
# Feature file shape: (2582, 32)
# 15 training_Guitar_Licks_06-12.wav.npy
# Feature file shape: (2582, 32)
# 16 training_Jaillet64.wav.npy
# Feature file shape: (2582, 32)
# 17 test_tambourine.wav.npy
# Feature file shape: (2582, 32)
# 18 training_piano_autumn.wav.npy
# Feature file shape: (2582, 32)
# 19 training_piano_02.wav.npy
# Feature file shape: (2582, 32)
# 20 test_ta_1mc08.wav.npy
# Feature file shape: (2582, 32)
# 21 training_violin2.wav.npy
# Feature file shape: (2582, 32)
# 22 test_piano_p5.wav.npy
# Feature file shape: (2582, 32)
# 23 training_ta_1eb08.wav.npy
# Feature file shape: (2582, 32)
# 24 training_celloTaksim_pt1.wav.npy
# Feature file shape: (2582, 32)
# 25 training_trumpet4.wav.npy
# Feature file shape: (2582, 32)
# 26 training_bongo1.wav.npy
# Feature file shape: (2582, 32)
# 27 training_ta_1eb03.wav.npy
# Feature file shape: (2582, 32)
# 28 training_piano_08.wav.npy
# Feature file shape: (2582, 32)
# 29 training_piano_p3.wav.npy
# Feature file shape: (2582, 32)
# 30 training_violin3.wav.npy
# Feature file shape: (2582, 32)
# 31 training_trumpet_chetbaker.wav.npy
# Feature file shape: (2582, 32)
# 32 test_triangle.wav.npy
# Feature file shape: (2582, 32)
# 33 training_Guitar_Licks_07-11.wav.npy
# Feature file shape: (2582, 32)
# 34 training_ud_06.wav.npy
# Feature file shape: (2582, 32)
# 35 training_clarinet1.wav.npy
# Feature file shape: (2582, 32)
# 36 training_ud_03.wav.npy
# Feature file shape: (2582, 32)
# 37 test_oud_taksimleri_pt1.wav.npy
# Feature file shape: (2582, 32)
# 38 training_violin1.wav.npy
# Feature file shape: (2582, 32)
# 39 training_Guitar_Licks_15-05.wav.npy
# Feature file shape: (2582, 32)
# 40 training_sax_stephenchai.wav.npy
# Feature file shape: (2582, 32)
# 41 test_ud_17.wav.npy
# Feature file shape: (2582, 32)
# 42 test_TexasMusicForge.wav.npy
# Feature file shape: (2582, 32)
# 43 training_kemence_01.wav.npy
# Feature file shape: (2582, 32)
# 44 test_violin_dark_eyes_viol.wav.npy
# Feature file shape: (2582, 32)
# 45 training_guitar1.wav.npy
# Feature file shape: (2582, 32)
# 46 training_conga1.wav.npy
# Feature file shape: (2582, 32)
# 47 training_mixtures_jazz3.wav.npy
# Feature file shape: (2582, 32)
# 48 training_Guitar_Licks_07-06.wav.npy
# Feature file shape: (2582, 32)
# 49 training_ne_icm05.wav.npy
# Feature file shape: (2582, 32)
# 50 training_castagnet1.wav.npy
# Feature file shape: (2582, 32)
# 51 training_oud_rast_taksim1.wav.npy
# Feature file shape: (2582, 32)
# 52 training_ta_1eb06.wav.npy
# Feature file shape: (2582, 32)
# 53 training_piano_corea_08.wav.npy
# Feature file shape: (2582, 32)
# 54 training_sax_12.wav.npy
# Feature file shape: (2582, 32)
# 55 training_Guitar_Licks_15-06.wav.npy
# Feature file shape: (2582, 32)
# 56 test_trumpet33.wav.npy
# Feature file shape: (2582, 32)
# 57 training_Cello_Sonata_3_pt1.wav.npy
# Feature file shape: (2582, 32)
# 58 training_kemence_11.wav.npy
# Feature file shape: (2582, 32)
# 59 training_oud_8.wav.npy
# Feature file shape: (2582, 32)
# 60 training_kamence_10.wav.npy
# Feature file shape: (2582, 32)
# 61 test_CelloTaksimi_pt1.wav.npy
# Feature file shape: (2582, 32)
# 62 training_clarinet_SL1_pt1.wav.npy
# Feature file shape: (2582, 32)
# 63 test_ne_tmu2n06.wav.npy
# Feature file shape: (2582, 32)
# 64 training_piano_corea_03.wav.npy
# Feature file shape: (2582, 32)
# 65 training_cello1.wav.npy
# Feature file shape: (2582, 32)
# 66 training_piano_full.wav.npy
# Feature file shape: (2582, 32)
# 67 training_ud_04.wav.npy
# Feature file shape: (2582, 32)
# 68 training_violin_03__kurdilihicazkar__keman.wav.npy
# Feature file shape: (2582, 32)
# 69 training_mixtures_classic2.wav.npy
# Feature file shape: (2582, 32)
# 70 training_trumpet1.wav.npy
# Feature file shape: (2582, 32)
# 71 training_ud_02.wav.npy
# Feature file shape: (2582, 32)
# 72 training_mixtures_classic3.wav.npy
# Feature file shape: (2582, 32)
# 73 training_ne_icm09.wav.npy
# Feature file shape: (2582, 32)
# 74 training_ne_se01.wav.npy
# Feature file shape: (2582, 32)
# 75 training_ne_se03.wav.npy
# Feature file shape: (2582, 32)
# 76 training_guitar3.wav.npy
# Feature file shape: (2582, 32)
# 77 training_ta_1eb07.wav.npy
# Feature file shape: (2582, 32)
# 78 training_guitar2.wav.npy
# Feature file shape: (2582, 32)
# 79 training_mixtures_jazz2.wav.npy
# Feature file shape: (2582, 32)
# 80 test_violin4.wav.npy
# Feature file shape: (2582, 32)
# 81 training_clarinet_44784_pt1.wav.npy
# Feature file shape: (2582, 32)
# 82 training_sax_06.wav.npy
# Feature file shape: (2582, 32)
# 83 test_piano1.wav.npy
# Feature file shape: (2582, 32)
# 84 test_sax1.wav.npy
# Feature file shape: (2582, 32)
# 85 training_violin_01_hicaz.wav.npy
# Feature file shape: (2582, 32)
# 86 test_kemence_22.wav.npy
# Feature file shape: (2582, 32)
# 87 training_clarinet_44361.wav.npy
# Feature file shape: (2582, 32)
# 88 training_piano_MOON.wav.npy
# Feature file shape: (2582, 32)
# 89 test_mixtures_pop1.wav.npy
# Feature file shape: (2582, 32)
# 90 training_techno2.wav.npy
# Feature file shape: (2582, 32)
# 91 test_jazz3.wav.npy
# Feature file shape: (2582, 32)
# 92 training_synthbass1.wav.npy
# Feature file shape: (2582, 32)
# 93 training_distguit1.wav.npy
# Feature file shape: (2582, 32)
# 94 training_leveau_techno2.wav.npy
# Feature file shape: (2582, 32)
# 95 test_leveau_jazz3.wav.npy
# Feature file shape: (2582, 32)
# 96 test_leveau_classic3.wav.npy
# Feature file shape: (2582, 32)
# 97 training_leveau_synthbass1.wav.npy
# Feature file shape: (2582, 32)
# 98 training_leveau_distguit1.wav.npy
# Feature file shape: (2582, 32)
# 99 test_leveau_guitar3.wav.npy
# Feature file shape: (2582, 32)
# 100 training_leveau_cello1.wav.npy
# Feature file shape: (2582, 32)
# 101 training_leveau_classic2.wav.npy
# Feature file shape: (2582, 32)
# 102 training_leveau_guitar2.wav.npy
# Feature file shape: (2582, 32)
# 103 training_leveau_jazz2.wav.npy
# Feature file shape: (2582, 32)
# 104 training_leveau_piano1.wav.npy
# Feature file shape: (2582, 32)
# 105 training_leveau_pop1.wav.npy
# Feature file shape: (2582, 32)
# 106 training_leveau_sax1.wav.npy
# Feature file shape: (2582, 32)
# 107 training_leveau_trumpet1.wav.npy
# Feature file shape: (2582, 32)
# 108 training_leveau_violin2.wav.npy
# Feature file shape: (2582, 32)
# 109 training_leveau_rock1.wav.npy
# Feature file shape: (2582, 32)
# normalized files written to drive/My Drive/dataset_MIR/final_dataset_try/log_mel_spectogram_norm/ folder and the scaler to drive/My Drive/dataset_MIR/final_dataset_try/logmel_spect_wts
# Normalized 109 files

# %%
#@title
#label extraction
print(os.listdir(txt_path))
for file_cnt, file_name in enumerate(os.listdir(txt_path)):
  if file_name != '.DS_Store':
    print('file_cnt {}, file_name {}'.format(file_cnt, file_name))
    desc_file = read_desc_file(os.path.join(txt_path, file_name))
    #giving the same name extension to the file in order to make easier the processing of the file in the future instructions
    wav_filename = '{}.wav'.format(file_name.split('.')[0])
    labels = get_labels_for_file(desc_file)
    #reshape of the file to be processed correctly for the networks
    labels = labels.reshape(labels.shape[0], 1)
    print("Label file shape: {}".format(labels.shape))
    np.save(os.path.join(label_path, wav_filename), labels)

print("File which have been processed: ", file_cnt)
# Out:
# ['training_kemence_08.txt', 'training_SummerTogether.txt', 'training_sax_george.txt', 'test_tambourine.txt', 'training_Cello_Suite_Preludium.txt', 'training_tabla.txt', 'training_DiverseTaksim_pt1.txt', 'training_violin_hoochie.txt', 'training_Guitar_Licks_51-10.txt', 'test_mixtures_rock1.txt', 'training_Guitar_Licks_06-11.txt', 'training_oud_1.txt', 'test_violin_dark_eyes_viol.txt', 'training_ne_icm05.txt', 'training_ta_1eb08.txt', 'training_Guitar_Licks_06-12.txt', 'test_ne_se04.txt', 'training_piano_mussorgsky.txt', 'training_violin1.txt', 'training_trumpet_02.txt', 'training_piano_corea_08.txt', 'training_ne_icm13.txt', 'training_violin2.txt', 'training_clarinet_SL1_pt1.txt', 'training_celloTaksim_pt1.txt', 'training_kamence_10.txt', 'test_ne_tmu2n06.txt', 'training_piano_02.txt', 'training_bongo1.txt', 'training_clarinet1.txt', 'training_Jaillet64.txt', 'training_violin3.txt', 'test_ta_1mc08.txt', 'training_Cello_Sonata_3_pt1.txt', 'training_violin_03__kurdilihicazkar__keman.txt', 'training_piano_p3.txt', 'test_triangle.txt', 'test_oud_taksimleri_pt1.txt', 'training_ud_06.txt', 'training_piano_autumn.txt', 'test_piano_p5.txt', 'training_ud_04.txt', 'training_piano_full.txt', 'training_piano_08.txt', 'training_cello1.txt', 'training_piano_corea_03.txt', 'training_ta_1eb03.txt', 'training_trumpet_chetbaker.txt', 'training_trumpet4.txt', 'training_ne_se03.txt', 'training_guitar3.txt', 'training_Guitar_Licks_07-06.txt', 'training_castagnet1.txt', 'training_ta_1eb06.txt', 'training_Guitar_Licks_15-06.txt', 'training_Guitar_Licks_15-05.txt', 'test_ud_17.txt', 'training_trumpet1.txt', 'training_guitar2.txt', 'training_ud_03.txt', 'training_ta_1eb07.txt', 'training_sax_stephenchai.txt', 'training_Guitar_Licks_07-11.txt', 'training_mixtures_classic2.txt', 'training_mixtures_classic3.txt', 'training_ud_02.txt', 'test_TexasMusicForge.txt', 'training_guitar1.txt', 'training_ne_icm09.txt', 'training_conga1.txt', 'test_piano1.txt', 'training_sax_06.txt', 'test_violin4.txt', 'training_clarinet_44784_pt1.txt', 'training_mixtures_jazz3.txt', 'training_oud_rast_taksim1.txt', 'training_ne_se01.txt', 'training_mixtures_jazz2.txt', 'training_sax_12.txt', 'training_kemence_01.txt', 'training_kemence_11.txt', 'training_piano_MOON.txt', 'test_mixtures_pop1.txt', 'test_CelloTaksimi_pt1.txt', 'training_oud_8.txt', 'test_kemence_22.txt', 'test_trumpet33.txt', 'training_violin_01_hicaz.txt', 'test_sax1.txt', 'training_clarinet_44361.txt', 'test_leveau_classic3.csv', 'test_leveau_jazz3.csv', 'training_leveau_pop1.csv', 'training_leveau_jazz2.csv', 'training_leveau_distguit1.csv', 'training_leveau_classic2.csv', 'training_leveau_guitar2.csv', 'training_leveau_cello1.csv', 'training_leveau_piano1.csv', 'test_leveau_guitar3.csv', 'training_leveau_rock1.csv', 'training_leveau_synthbass1.csv', 'training_leveau_sax1.csv', 'training_leveau_trumpet1.csv', 'training_leveau_violin2.csv', 'training_leveau_techno2.csv']
# file_cnt 0, file_name training_kemence_08.txt
# Label file shape: (2582, 1)
# file_cnt 1, file_name training_SummerTogether.txt
# Label file shape: (2582, 1)
# file_cnt 2, file_name training_sax_george.txt
# Label file shape: (2582, 1)
# file_cnt 3, file_name test_tambourine.txt
# Label file shape: (2582, 1)
# file_cnt 4, file_name training_Cello_Suite_Preludium.txt
# Label file shape: (2582, 1)
# file_cnt 5, file_name training_tabla.txt
# Label file shape: (2582, 1)
# file_cnt 6, file_name training_DiverseTaksim_pt1.txt
# Label file shape: (2582, 1)
# file_cnt 7, file_name training_violin_hoochie.txt
# Label file shape: (2582, 1)
# file_cnt 8, file_name training_Guitar_Licks_51-10.txt
# Label file shape: (2582, 1)
# file_cnt 9, file_name test_mixtures_rock1.txt
# Label file shape: (2582, 1)
# file_cnt 10, file_name training_Guitar_Licks_06-11.txt
# Label file shape: (2582, 1)
# file_cnt 11, file_name training_oud_1.txt
# Label file shape: (2582, 1)
# file_cnt 12, file_name test_violin_dark_eyes_viol.txt
# Label file shape: (2582, 1)
# file_cnt 13, file_name training_ne_icm05.txt
# Label file shape: (2582, 1)
# file_cnt 14, file_name training_ta_1eb08.txt
# Label file shape: (2582, 1)
# file_cnt 15, file_name training_Guitar_Licks_06-12.txt
# Label file shape: (2582, 1)
# file_cnt 16, file_name test_ne_se04.txt
# Label file shape: (2582, 1)
# file_cnt 17, file_name training_piano_mussorgsky.txt
# Label file shape: (2582, 1)
# file_cnt 18, file_name training_violin1.txt
# Label file shape: (2582, 1)
# file_cnt 19, file_name training_trumpet_02.txt
# Label file shape: (2582, 1)
# file_cnt 20, file_name training_piano_corea_08.txt
# Label file shape: (2582, 1)
# file_cnt 21, file_name training_ne_icm13.txt
# Label file shape: (2582, 1)
# file_cnt 22, file_name training_violin2.txt
# Label file shape: (2582, 1)
# file_cnt 23, file_name training_clarinet_SL1_pt1.txt
# Label file shape: (2582, 1)
# file_cnt 24, file_name training_celloTaksim_pt1.txt
# Label file shape: (2582, 1)
# file_cnt 25, file_name training_kamence_10.txt
# Label file shape: (2582, 1)
# file_cnt 26, file_name test_ne_tmu2n06.txt
# Label file shape: (2582, 1)
# file_cnt 27, file_name training_piano_02.txt
# Label file shape: (2582, 1)
# file_cnt 28, file_name training_bongo1.txt
# Label file shape: (2582, 1)
# file_cnt 29, file_name training_clarinet1.txt
# Label file shape: (2582, 1)
# file_cnt 30, file_name training_Jaillet64.txt
# Label file shape: (2582, 1)
# file_cnt 31, file_name training_violin3.txt
# Label file shape: (2582, 1)
# file_cnt 32, file_name test_ta_1mc08.txt
# Label file shape: (2582, 1)
# file_cnt 33, file_name training_Cello_Sonata_3_pt1.txt
# Label file shape: (2582, 1)
# file_cnt 34, file_name training_violin_03__kurdilihicazkar__keman.txt
# Label file shape: (2582, 1)
# file_cnt 35, file_name training_piano_p3.txt
# Label file shape: (2582, 1)
# file_cnt 36, file_name test_triangle.txt
# Label file shape: (2582, 1)
# file_cnt 37, file_name test_oud_taksimleri_pt1.txt
# Label file shape: (2582, 1)
# file_cnt 38, file_name training_ud_06.txt
# Label file shape: (2582, 1)
# file_cnt 39, file_name training_piano_autumn.txt
# Label file shape: (2582, 1)
# file_cnt 40, file_name test_piano_p5.txt
# Label file shape: (2582, 1)
# file_cnt 41, file_name training_ud_04.txt
# Label file shape: (2582, 1)
# file_cnt 42, file_name training_piano_full.txt
# Label file shape: (2582, 1)
# file_cnt 43, file_name training_piano_08.txt
# Label file shape: (2582, 1)
# file_cnt 44, file_name training_cello1.txt
# Label file shape: (2582, 1)
# file_cnt 45, file_name training_piano_corea_03.txt
# Label file shape: (2582, 1)
# file_cnt 46, file_name training_ta_1eb03.txt
# Label file shape: (2582, 1)
# file_cnt 47, file_name training_trumpet_chetbaker.txt
# Label file shape: (2582, 1)
# file_cnt 48, file_name training_trumpet4.txt
# Label file shape: (2582, 1)
# file_cnt 49, file_name training_ne_se03.txt
# Label file shape: (2582, 1)
# file_cnt 50, file_name training_guitar3.txt
# Label file shape: (2582, 1)
# file_cnt 51, file_name training_Guitar_Licks_07-06.txt
# Label file shape: (2582, 1)
# file_cnt 52, file_name training_castagnet1.txt
# Label file shape: (2582, 1)
# file_cnt 53, file_name training_ta_1eb06.txt
# Label file shape: (2582, 1)
# file_cnt 54, file_name training_Guitar_Licks_15-06.txt
# Label file shape: (2582, 1)
# file_cnt 55, file_name training_Guitar_Licks_15-05.txt
# Label file shape: (2582, 1)
# file_cnt 56, file_name test_ud_17.txt
# Label file shape: (2582, 1)
# file_cnt 57, file_name training_trumpet1.txt
# Label file shape: (2582, 1)
# file_cnt 58, file_name training_guitar2.txt
# Label file shape: (2582, 1)
# file_cnt 59, file_name training_ud_03.txt
# Label file shape: (2582, 1)
# file_cnt 60, file_name training_ta_1eb07.txt
# Label file shape: (2582, 1)
# file_cnt 61, file_name training_sax_stephenchai.txt
# Label file shape: (2582, 1)
# file_cnt 62, file_name training_Guitar_Licks_07-11.txt
# Label file shape: (2582, 1)
# file_cnt 63, file_name training_mixtures_classic2.txt
# Label file shape: (2582, 1)
# file_cnt 64, file_name training_mixtures_classic3.txt
# Label file shape: (2582, 1)
# file_cnt 65, file_name training_ud_02.txt
# Label file shape: (2582, 1)
# file_cnt 66, file_name test_TexasMusicForge.txt
# Label file shape: (2582, 1)
# file_cnt 67, file_name training_guitar1.txt
# Label file shape: (2582, 1)
# file_cnt 68, file_name training_ne_icm09.txt
# Label file shape: (2582, 1)
# file_cnt 69, file_name training_conga1.txt
# Label file shape: (2582, 1)
# file_cnt 70, file_name test_piano1.txt
# Label file shape: (2582, 1)
# file_cnt 71, file_name training_sax_06.txt
# Label file shape: (2582, 1)
# file_cnt 72, file_name test_violin4.txt
# Label file shape: (2582, 1)
# file_cnt 73, file_name training_clarinet_44784_pt1.txt
# Label file shape: (2582, 1)
# file_cnt 74, file_name training_mixtures_jazz3.txt
# Label file shape: (2582, 1)
# file_cnt 75, file_name training_oud_rast_taksim1.txt
# Label file shape: (2582, 1)
# file_cnt 76, file_name training_ne_se01.txt
# Label file shape: (2582, 1)
# file_cnt 77, file_name training_mixtures_jazz2.txt
# Label file shape: (2582, 1)
# file_cnt 78, file_name training_sax_12.txt
# Label file shape: (2582, 1)
# file_cnt 79, file_name training_kemence_01.txt
# Label file shape: (2582, 1)
# file_cnt 80, file_name training_kemence_11.txt
# Label file shape: (2582, 1)
# file_cnt 81, file_name training_piano_MOON.txt
# Label file shape: (2582, 1)
# file_cnt 82, file_name test_mixtures_pop1.txt
# Label file shape: (2582, 1)
# file_cnt 83, file_name test_CelloTaksimi_pt1.txt
# Label file shape: (2582, 1)
# file_cnt 84, file_name training_oud_8.txt
# Label file shape: (2582, 1)
# file_cnt 85, file_name test_kemence_22.txt
# Label file shape: (2582, 1)
# file_cnt 86, file_name test_trumpet33.txt
# Label file shape: (2582, 1)
# file_cnt 87, file_name training_violin_01_hicaz.txt
# Label file shape: (2582, 1)
# file_cnt 88, file_name test_sax1.txt
# Label file shape: (2582, 1)
# file_cnt 89, file_name training_clarinet_44361.txt
# Label file shape: (2582, 1)
# file_cnt 90, file_name test_leveau_classic3.csv
# Label file shape: (2582, 1)
# file_cnt 91, file_name test_leveau_jazz3.csv
# Label file shape: (2582, 1)
# file_cnt 92, file_name training_leveau_pop1.csv
# Label file shape: (2582, 1)
# file_cnt 93, file_name training_leveau_jazz2.csv
# Label file shape: (2582, 1)
# file_cnt 94, file_name training_leveau_distguit1.csv
# Label file shape: (2582, 1)
# file_cnt 95, file_name training_leveau_classic2.csv
# Label file shape: (2582, 1)
# file_cnt 96, file_name training_leveau_guitar2.csv
# Label file shape: (2582, 1)
# file_cnt 97, file_name training_leveau_cello1.csv
# Label file shape: (2582, 1)
# file_cnt 98, file_name training_leveau_piano1.csv
# Label file shape: (2582, 1)
# file_cnt 99, file_name test_leveau_guitar3.csv
# Label file shape: (2582, 1)
# file_cnt 100, file_name training_leveau_rock1.csv
# Label file shape: (2582, 1)
# file_cnt 101, file_name training_leveau_synthbass1.csv
# Label file shape: (2582, 1)
# file_cnt 102, file_name training_leveau_sax1.csv
# Label file shape: (2582, 1)
# file_cnt 103, file_name training_leveau_trumpet1.csv
# Label file shape: (2582, 1)
# file_cnt 104, file_name training_leveau_violin2.csv
# Label file shape: (2582, 1)
# file_cnt 105, file_name training_leveau_techno2.csv
# Label file shape: (2582, 1)
# File which have been processed:  105

# %% [markdown]
# ## Neural Network - Training and Evaluation
#
# In this part of the code, the different neural network will be trained and evaluated. In particular, we are going to train three different CRNN with different hyper-paramater:
# - Squared (kernel filter 3x3)
# - High (kernel filter 6x2)
# - Wide (kernel filter 2x6)
#
#
# Each of them used different kernel filter size and each of them will be trained with different combination of batch size and sequence lenght in order to find the combination which give the best performance.
# The CRNN networks will be evaluated in terms of accurcay and F1-score and the relatives confusion matrices will be printed.

# %% [markdown]
# ### Definition of hyper-parameter
#
# CRNN - In the next sections we will define the hyper-paramater which will be used in ecah different network which we will train and evaluate (such as CNN units, RNN units, FC units, etc.) together with the generator of the training and testing batches and function to collect ground truth labels.
# Further details of the network can be found in the report LINK TO REPORT

# %%
#collection of the ground truth label for the test dataset
def collect_test_labels(_data_gen_test, _data_out, quick_test):
     '''
     The function collect the label for the ground truth. 
     Input parameters: 
      ---------------------
      :_data_gen_test: generator for the test dataset
      : _data_out: data output
      : quick_test: 1 for quick test, 0 for no quick test
      Return:
      ------------
      gruund truth label
     '''

     nb_batch = 1 if quick_test else _data_gen_test.get_total_batches_in_data()
     batch_size = _data_out[0]
     gt_sed = np.zeros((nb_batch * batch_size, _data_out[1], _data_out[2]))
     cnt = 0
     for tmp_feat, tmp_label in _data_gen_test.generate():
         gt_sed[cnt * batch_size:(cnt + 1) * batch_size, :, :] = tmp_label[0]
         cnt = cnt + 1
         if cnt == nb_batch:
             break
     return gt_sed.astype(int)

# %%
# Parameters used in the feature extraction, neural network model, and training the CRNN network can be changed here.

#function to get parameters for the model
def get_params():
    '''
    Return:
    --------
        :params: dictionary with parameters specified according to dataset and training model
    '''
    # ########### default parameters ##############
    params = dict(
        quick_test=False,    # To do quick test. Trains/test on small subset of dataset
        nfft=512,          # FFT/window length size
        # DNN Model parameters
        sequence_length=1,           # Feature sequence length
        batch_size=1,               # Batch size 
        dropout_rate=0.0,           # Dropout rate, constant for all layers
        nb_cnn2d_filt=64,           # Number of CNN nodes, constant for each layer
        pool_size=[2, 2, 2],        # CNN pooling, length of list = number of CNN layers, list value = pooling per layer
        rnn_size=[128, 128],        # RNN contents, length of list = number of layers, list value = number of nodes
        fnn_size=[128],             # FNN contents, length of list = number of layers, list value = number of nodes
        loss_weights=[1.],          # weights
        nb_epochs=1,                # Train for maximum epochs (one forward pass and one backward pass for all training examples)
                                  
    )

    for key, value in params.items():
        print("{}: {}".format(key, value))
    return params

# %%
# Data generator for training batch size 

import numpy as np
from numpy.random import seed
seed(1)
import os
from IPython import embed
from collections import deque
import random


class DataGenerator(object):
    def __init__(
            self, datagen_mode='train', batch_size=4, seq_len=216,
            shuffle=True, nfft=512, extra_name=''
    ):

        self._datagen_mode = datagen_mode
        self._batch_size = batch_size
        self._seq_len = seq_len
        self._shuffle = shuffle
        self._label_dir = os.path.join(dataset_folder, 'labels')
        self._feat_dir = os.path.join(dataset_folder, 'Spect_norma')

        self._filenames_list = list()
        self._nb_frames_file = None                   # Assuming number of frames in feat files are the same
        self._feat_len = None
        self._nb_ch = 2                               #(multiply per due )
        self._label_len = None                        
        self._nb_classes = 1
        self._get_label_filenames_sizes()


        self._batch_seq_len = self._batch_size*self._seq_len
        self._circ_buf_feat = None
        self._circ_buf_label = None


        self._nb_total_batches = int(np.floor((len(self._filenames_list) * self._nb_frames_file /
                                               float(self._seq_len * self._batch_size))))

    #function to get labels shapes and features shape
    def get_data_sizes(self):
        '''
        Function to retrieve information regarding features shape and label shape.
        Returns:
        --------
            : feat_shape and label_shape, tuple and list of of label and features shapes
        '''
        #features shape
        feat_shape = (self._batch_size, self._nb_ch, self._seq_len, int(self._feat_len))
        #first label for class
        label_shape = (self._batch_size, self._seq_len, self._nb_classes)

        return feat_shape, label_shape

    #function to get total number of batches in data
    def get_total_batches_in_data(self):
        '''
        Function to the total number of batches
        Return:
        --------
            : total number of batches
        '''
        print("Total number of batches in {}: {}".format(self._datagen_mode, self._nb_total_batches))
        return self._nb_total_batches

    #function to get information according to the dataset
    def _get_label_filenames_sizes(self):
        '''
        The function retrieves all the file belonging to the specified dataset type
        '''
        training_file_count = 0

        for filename in os.listdir(self._label_dir):
            if self._datagen_mode in filename:
                training_file_count += 1
                self._filenames_list.append(filename)

        temp_feat = np.load(os.path.join(self._feat_dir, self._filenames_list[0]))

        #number of frames per file and features length
        self._nb_frames_file = temp_feat.shape[0]
        self._feat_len = temp_feat.shape[1] / self._nb_ch
      
        temp_label = np.load(os.path.join(self._label_dir, self._filenames_list[0]))
        #label length 
        self._label_len = temp_label.shape[-1]
    
        return

    #genearator
    def generate(self):
        """
        Generates batches of samples
        :return:
        """

        while 1:
            if self._shuffle:
                random.shuffle(self._filenames_list)

            # Ideally this should have been outside the while loop. But while generating the test data we want the data
            # to be the same exactly for all epoch's hence we keep it here.
            self._circ_buf_feat = deque()
            self._circ_buf_label = deque()

            file_cnt = 0

            for i in range(self._nb_total_batches):

                # load feat and label to circular buffer. Always maintain at least one batch worth feat and label in the
                # circular buffer. If not keep refilling it.
                
                #creation of the batches.
                while len(self._circ_buf_feat) < self._batch_seq_len:


                    temp_feat = np.load(os.path.join(self._feat_dir, self._filenames_list[file_cnt]))
                    temp_label = np.load(os.path.join(self._label_dir, self._filenames_list[file_cnt]))


                    for row_cnt, row in enumerate(temp_feat):

                        self._circ_buf_feat.append(row)
                        self._circ_buf_label.append(temp_label[row_cnt])

                    file_cnt = file_cnt + 1

                # Read one batch size from the circular buffer
                feat = np.zeros((self._batch_seq_len, int(self._feat_len) * self._nb_ch))
                label = np.zeros((self._batch_seq_len, self._label_len))

                for j in range(self._batch_seq_len):
                    feat[j, :] = self._circ_buf_feat.popleft()
                    label[j, :] = self._circ_buf_label.popleft()
                feat = np.reshape(feat, (self._batch_seq_len, int(self._feat_len), self._nb_ch))


                # Split to sequences
                # making the data the same dimensions as the labels and the features
                feat = self._split_in_seqs(feat)
                label = self._split_in_seqs(label)

                yield feat, label

    def _split_in_seqs(self, data):
        if len(data.shape) == 1:
            if data.shape[0] % self._seq_len:
                data = data[:-(data.shape[0] % self._seq_len), :]
            data = data.reshape((int(data.shape[0] / self._seq_len), self._seq_len, 1))
        elif len(data.shape) == 2:
            if data.shape[0] % self._seq_len:
                data = data[:-(data.shape[0] % self._seq_len), :]
            data = data.reshape((int(data.shape[0] / self._seq_len), self._seq_len, data.shape[1]))
        elif len(data.shape) == 3:
            if data.shape[0] % self._seq_len:
                data = data[:-(data.shape[0] % self._seq_len), :, :]
            data = data.reshape((int(data.shape[0] / self._seq_len), self._seq_len, data.shape[1], data.shape[2]))
        else:
            print('ERROR: Unknown data dimensions: {}'.format(data.shape))
            exit()
        return data

# %%
#label reshape
def reshape_3Dto2D(A):
    return A.reshape(A.shape[0] * A.shape[1], A.shape[2])

# %%
params = get_params()
# Out:
# quick_test: False
# nfft: 512
# sequence_length: 1
# batch_size: 1
# dropout_rate: 0.0
# nb_cnn2d_filt: 64
# pool_size: [2, 2, 2]
# rnn_size: [128, 128]
# fnn_size: [128]
# loss_weights: [1.0]
# nb_epochs: 1

# %%
#lets create the folder where all the predictions will be saved
prediction_folder = dataset_folder + 'predictions_log_mel/'
label_for_prediction_folder = dataset_folder + 'prediction_labels_log_mel/'
create_folder(prediction_folder)
create_folder(label_for_prediction_folder)

# %% [markdown]
# ## Squared CRNN architecture, kernel filter size 3x3

# %%
#lets create the folder for the squared predictions
squared_pred_path = prediction_folder + 'squared_pred/'
squared_pred_lab_path = label_for_prediction_folder + 'squared_pred_lab/'
create_folder(squared_pred_path)
create_folder(squared_pred_lab_path)

# %%
from numpy.random import seed
seed(1)
import tensorflow as ts
from tensorflow.keras.layers import Bidirectional, Conv2D, MaxPool2D, Input, MaxPooling3D, Conv3D
from tensorflow.keras.layers import Dense, Activation, Dropout, Reshape, Permute
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.optimizers import Adam

ts.keras.backend.set_image_data_format('channels_last')

def get_model_squared(data_in, data_out, dropout_rate, nb_cnn2d_filt, pool_size,
              rnn_size, fnn_size, weights, first):

    #initial dimension set for channel last
    spec_start = Input(shape=(data_in[2], data_in[3], data_in[1]))
    #dimension for cnn same as the starting point
    spec_cnn = spec_start
    for i, convCount in enumerate(pool_size):
        #convolutional layer with squared kernel size
        spec_cnn = Conv2D(filters=nb_cnn2d_filt, kernel_size=(3, 3), padding='same')(spec_cnn)
        spec_cnn = BatchNormalization(trainable=True)(spec_cnn, training=True)
        spec_cnn = Activation('relu')(spec_cnn)
        spec_cnn = MaxPool2D(pool_size=(1, pool_size[i]))(spec_cnn)

    #reshape to a proper dimension for recurrent layers
    spec_rnn = Reshape((data_in[2], 2*nb_cnn2d_filt))(spec_cnn)

    for nb_rnn_filt in rnn_size:
        spec_rnn = Bidirectional(
            GRU(nb_rnn_filt, activation='tanh', dropout=dropout_rate, recurrent_dropout=dropout_rate,
                return_sequences=True, reset_after=False), 
            merge_mode='mul'
        )(spec_rnn, training=True)

    sed = spec_rnn
    sed = TimeDistributed(Dense(fnn_size[0]))(sed)
    sed = TimeDistributed(Dense(data_out[-1]))(sed)
    sed = Activation('sigmoid', name='sed_out')(sed)

    model = Model(inputs=spec_start, outputs=[sed])
    model.compile(optimizer=Adam(), loss=['binary_crossentropy'], loss_weights=weights)

    if first:
      model.summary()
    return model

# %%
import numpy as np
from numpy.random import seed
seed(1)
import sys
import os
import time
import matplotlib.pyplot as plot
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# get all the parameters i need for the project
nb_epochs = 25 #if changed all the prediction need to be re-done so please delete the file inside the folders and start the code again. 
first = 1


#loop trough the different epochs, sequence lenghth and batch size:
for seq_lenght in [256, 128, 64]:
  for batch_size in [16, 8, 4]:
    
    params['sequence_length'] = seq_lenght
    params['batch_size'] = batch_size
    params['nb_epochs'] = nb_epochs
    
    print('-------------------------------------------')
    
    print("Batch size: ", batch_size)
    print("seq_lenght: ", seq_lenght)
    pred_filename = '/pred_{}_{}'.format(batch_size, seq_lenght)
    #if the prediction is already done, skip it. Please, consider to delete the file if the number of epochs is changed 
    if os.path.exists(os.path.join(squared_pred_path + pred_filename + '.npy')):
      print("Prediction for batch size {0} and seq lenght {1} with squared filters already done".format(batch_size, seq_lenght))
    else:

      print("Path to file: ", os.path.join(squared_pred_path + pred_filename))

      data_gen_train = DataGenerator(
          nfft=params['nfft'],
          batch_size=params['batch_size'], seq_len=params['sequence_length'], datagen_mode='train'
      )


    # generation of testing dataset
      data_gen_test = DataGenerator(
         nfft=params['nfft'],
         batch_size=params['batch_size'], seq_len=params['sequence_length'], datagen_mode='test', shuffle=False
      )

      data_in, data_out = data_gen_train.get_data_sizes()
      print(data_in, data_out)

      model = get_model_squared(data_in=data_in, data_out=data_out, dropout_rate=params['dropout_rate'],
                  nb_cnn2d_filt=params['nb_cnn2d_filt'], pool_size=params['pool_size'],
                  rnn_size=params['rnn_size'], fnn_size=params['fnn_size'],
                  weights=params['loss_weights'], first=first)
    
      #so we do print the model only for the first case 
      first = 0

      gt = collect_test_labels(data_gen_test, data_out, params['quick_test'])
      #reshape to 2D
      sed_gt = reshape_3Dto2D(gt)
      file_path = os.path.join(squared_pred_lab_path + pred_filename + '_lab')
      print("File prediction saved: {}".format(file_path))
      np.save(file_path, sed_gt)
      print("File prediction saved: {}".format(file_path))

     # it returns an history value
     #model fit
      hist = model.fit(
          x=data_gen_train.generate(),
          steps_per_epoch=1 if params['quick_test'] else data_gen_train.get_total_batches_in_data(),
          validation_data=data_gen_test.generate(),
          validation_steps=1 if params['quick_test'] else data_gen_test.get_total_batches_in_data(),
          epochs=nb_epochs,
          verbose=1)

      #model predictions
      pred = model.predict(
          x=data_gen_test.generate(),
          steps=1 if params['quick_test'] else data_gen_test.get_total_batches_in_data(),
          verbose=0
      )
      
      #saving the files inside the prediction folder
      #training loss values
      hist_loss_filename = os.path.join(squared_pred_path + pred_filename) + '_hist_loss'
      np.save(hist_loss_filename, hist.history['loss'])
      print("File prediction loss saved {}".format(os.path.join(squared_pred_path + hist_loss_filename)))
      #validation loss values
      hist_val_loss_filename = os.path.join(squared_pred_path + pred_filename) + '_hist_val_loss'
      np.save(hist_val_loss_filename, hist.history['val_loss'])
      print("File prediction val_loss saved {}".format(os.path.join(squared_pred_path + hist_val_loss_filename))) 
      #prediction
      np.save(os.path.join(squared_pred_path + pred_filename), pred)
      print("File prediction saved {}".format(os.path.join(squared_pred_path + pred_filename)))
# Out:
# -------------------------------------------
# Batch size:  16
# seq_lenght:  256
# Prediction for batch size 16 and seq lenght 256 with squared filters already done
# -------------------------------------------
# Batch size:  8
# seq_lenght:  256
# Prediction for batch size 8 and seq lenght 256 with squared filters already done
# -------------------------------------------
# Batch size:  4
# seq_lenght:  256
# Prediction for batch size 4 and seq lenght 256 with squared filters already done
# -------------------------------------------
# Batch size:  16
# seq_lenght:  128
# Prediction for batch size 16 and seq lenght 128 with squared filters already done
# -------------------------------------------
# Batch size:  8
# seq_lenght:  128
# Prediction for batch size 8 and seq lenght 128 with squared filters already done
# -------------------------------------------
# Batch size:  4
# seq_lenght:  128
# Prediction for batch size 4 and seq lenght 128 with squared filters already done
# -------------------------------------------
# Batch size:  16
# seq_lenght:  64
# Prediction for batch size 16 and seq lenght 64 with squared filters already done
# -------------------------------------------
# Batch size:  8
# seq_lenght:  64
# Prediction for batch size 8 and seq lenght 64 with squared filters already done
# -------------------------------------------
# Batch size:  4
# seq_lenght:  64
# Prediction for batch size 4 and seq lenght 64 with squared filters already done

# %% [markdown]
# ## Evaluation squared CRNN architecture
#
# Evaluation in terms of F1-score and accuracy

# %%
#we retrieve all the information from the files and plot the results in terms of accurcay and F1_score
import matplotlib.pyplot as plt


for filename in os.listdir(squared_pred_path):
  if (filename.split('.')[0].split('_')[-1]) != 'loss': 
    print('----------------------------------------')
    tmp_pred = np.load(os.path.join(squared_pred_path, filename))
    hist_path_loss = filename.split('.')[0] + '_hist_loss.npy'
    hist_path_val_loss = filename.split('.')[0] + '_hist_val_loss.npy'
    pred_path = filename.split('.')[0] + '_lab.npy'
    tmp_hist_loss = np.load(os.path.join(squared_pred_path, hist_path_loss))
    tmp_hist_val_loss = np.load(os.path.join(squared_pred_path, hist_path_val_loss))
    #thresholding
    tmp_pred_re = reshape_3Dto2D(tmp_pred) > 0.7
    sed_gt = np.load(os.path.join(squared_pred_lab_path, pred_path))
    
    print("Prediction for batch size: {}, sequence lenght: {}".format(filename.split('_')[1], filename.split('_')[2].split('.')[0]))

    accuracy = accuracy_score(sed_gt, tmp_pred_re)
    print("Accuracy: ", accuracy)

    f1 = f1_score(sed_gt, tmp_pred_re, zero_division=1)
    print("F1: ", f1)

    # summarize history for trainign and validation loss
    plt.plot(tmp_hist_loss)
    plt.plot(tmp_hist_val_loss)
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()
# Out:
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 256
# Accuracy:  0.9863656850961539
# F1:  0.0
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 256
# Accuracy:  0.9887319711538461
# F1:  0.0
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 256
# Accuracy:  0.9869290865384616
# F1:  0.03064066852367688
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 128
# Accuracy:  0.9891263521634616
# F1:  0.0034423407917383822
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 128
# Accuracy:  0.9870042067307693
# F1:  0.017045454545454548
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 128
# Accuracy:  0.985546875
# F1:  0.06498194945848376
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 64
# Accuracy:  0.986083984375
# F1:  0.0
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 64
# Accuracy:  0.9858816964285714
# F1:  0.03802281368821293
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 64
# Accuracy:  0.9838381220379147
# F1:  0.09157127991675337

# %%
#we retrieve all the information from the files and print the confusioon matrices
import matplotlib.pyplot as plt
import seaborn as sns


for filename in os.listdir(squared_pred_path):
  if (filename.split('.')[0].split('_')[-1]) != 'loss': 
    print('----------------------------------------')
    tmp_pred = np.load(os.path.join(squared_pred_path, filename))
    hist_path_loss = filename.split('.')[0] + '_hist_loss.npy'
    hist_path_val_loss = filename.split('.')[0] + '_hist_val_loss.npy'
    pred_path = filename.split('.')[0] + '_lab.npy'
    tmp_hist_loss = np.load(os.path.join(squared_pred_path, hist_path_loss))
    tmp_hist_val_loss = np.load(os.path.join(squared_pred_path, hist_path_val_loss))
    #thresholding
    tmp_pred_re = reshape_3Dto2D(tmp_pred) > 0.7
    sed_gt = np.load(os.path.join(squared_pred_lab_path, pred_path))

    
    print("Prediction for batch size: {}, sequence lenght: {}".format(filename.split('_')[1], filename.split('_')[2].split('.')[0]))

    matrix_test = confusion_matrix(sed_gt, tmp_pred_re)
    print(matrix_test) 

    matrix_test_norm = confusion_matrix(sed_gt, tmp_pred_re, normalize='true') * 100 

    ax = sns.heatmap(matrix_test_norm, linewidth=0.5, annot=True, cmap="Blues", xticklabels= ['no onset', 'onset'], yticklabels= ['no onset','onset'])
    plt.show()
# Out:
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 256
# [[52522    22]
#  [  704     0]]
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 256
# [[52648    72]
#  [  528     0]]
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 256
# [[52541   107]
#  [  589    11]]
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 128
# [[52668    36]
#  [  543     1]]
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 128
# [[52550    98]
#  [  594     6]]
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 128
# [[52956   224]
#  [  553    27]]
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 64
# [[52507    53]
#  [  688     0]]
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 64
# [[52986   158]
#  [  601    15]]
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 64
# [[53099   285]
#  [  588    44]]

# %% [markdown]
# ## High CRNN archictecture, kernel filter size 6x2

# %%
#lets create the folder for the high prediction
high_pred_path = prediction_folder + 'high_pred'
high_pred_lab_path = label_for_prediction_folder + 'high_pred_lab'
create_folder(high_pred_path)
create_folder(high_pred_lab_path)

# %%
from numpy.random import seed
seed(1)
import tensorflow as ts
from tensorflow.keras.layers import Bidirectional, Conv2D, MaxPool2D, Input, MaxPooling3D, Conv3D
from tensorflow.keras.layers import Dense, Activation, Dropout, Reshape, Permute
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.optimizers import Adam

ts.keras.backend.set_image_data_format('channels_last')

def get_model_high(data_in, data_out, dropout_rate, nb_cnn2d_filt, pool_size,
              rnn_size, fnn_size, weights, first):

    #initial dimenison set for channel last
    spec_start = Input(shape=(data_in[2], data_in[3], data_in[1]))
    #dimension for cnn same as the starting point
    spec_cnn = spec_start
    for i, convCount in enumerate(pool_size):
        #convolutional layer - kernel filtr size 6x2
        spec_cnn = Conv2D(filters=nb_cnn2d_filt, kernel_size=(6, 2), padding='same')(spec_cnn)
        spec_cnn = BatchNormalization(trainable=True)(spec_cnn, training=True)
        spec_cnn = Activation('relu')(spec_cnn)
        spec_cnn = MaxPool2D(pool_size=(1, pool_size[i]))(spec_cnn)

    #reshape to a proper dimension for recurrent layers
    spec_rnn = Reshape((data_in[2], 2*nb_cnn2d_filt))(spec_cnn)
    for nb_rnn_filt in rnn_size:
        spec_rnn = Bidirectional(
            GRU(nb_rnn_filt, activation='tanh', dropout=dropout_rate, recurrent_dropout=dropout_rate,
                return_sequences=True, reset_after=False), #reset_after set to false to make it work, default value changed between the two versions
            merge_mode='mul'
        )(spec_rnn, training=True)

    #fc
    sed = spec_rnn
    sed = TimeDistributed(Dense(fnn_size[0]))(sed)
    sed = TimeDistributed(Dense(data_out[-1]))(sed)
    sed = Activation('sigmoid', name='sed_out')(sed)

    model = Model(inputs=spec_start, outputs=[sed])
    model.compile(optimizer=Adam(), loss=['binary_crossentropy'], loss_weights=weights)

    if first:
      model.summary()
    return model

# %%
import numpy as np
from numpy.random import seed
seed(1)
import sys
import os
import time
import matplotlib.pyplot as plot
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# get all the parameters i need for the project
nb_epochs = 25 #if changed all the prediction need to be re-done so please delete the file inside the folders and start the code again. 
first = 1


#loop trough the different epochs, sequence lenghth and batch size:
for seq_lenght in [256, 126, 64]:
  for batch_size in [16, 8, 4]:
    
    params['sequence_length'] = seq_lenght
    params['batch_size'] = batch_size
    params['nb_epochs'] = nb_epochs
    
    print('-------------------------------------------')
    
    print("Batch size: ", batch_size)
    print("seq_lenght: ", seq_lenght)
    pred_filename = '/pred_{}_{}'.format(batch_size, seq_lenght) 
    if os.path.exists(os.path.join(high_pred_path + pred_filename + '.npy')):
      print("Prediction for batch size {0} and seq lenght {1} with squared filters already done".format(batch_size, seq_lenght))
    else:

      print("Path to file: ", os.path.join(high_pred_path + pred_filename))

      data_gen_train = DataGenerator(
          nfft=params['nfft'],
          batch_size=params['batch_size'], seq_len=params['sequence_length'], datagen_mode='train'
      )


    # generation of testing dataset
      data_gen_test = DataGenerator(
         nfft=params['nfft'],
         batch_size=params['batch_size'], seq_len=params['sequence_length'], datagen_mode='test', shuffle=False
      )

      data_in, data_out = data_gen_train.get_data_sizes()

      model = get_model_high(data_in=data_in, data_out=data_out, dropout_rate=params['dropout_rate'],
                  nb_cnn2d_filt=params['nb_cnn2d_filt'], pool_size=params['pool_size'],
                  rnn_size=params['rnn_size'], fnn_size=params['fnn_size'],
                  weights=params['loss_weights'], first=first)
    
      #so we do print the model only for the first case 
      first = 0

      gt = collect_test_labels(data_gen_test, data_out, params['quick_test'])
      #reshape to 2D
      sed_gt = reshape_3Dto2D(gt)
      file_path = os.path.join(high_pred_lab_path + pred_filename + '_lab')
      print("File prediction saved: {}".format(file_path))
      np.save(file_path, sed_gt)
      print("File prediction saved: {}".format(file_path))


     # it returns an history value
     #model fit
      hist = model.fit(
          x=data_gen_train.generate(),
          steps_per_epoch=1 if params['quick_test'] else data_gen_train.get_total_batches_in_data(),
          validation_data=data_gen_test.generate(),
          validation_steps=1 if params['quick_test'] else data_gen_test.get_total_batches_in_data(),
          epochs=nb_epochs,
          verbose=1)
      
      #model predict 
      pred = model.predict(
          x=data_gen_test.generate(),
          steps=1 if params['quick_test'] else data_gen_test.get_total_batches_in_data(),
          verbose=0
      )

      #training loss values
      hist_loss_filename = os.path.join(high_pred_path + pred_filename) + '_hist_loss'
      np.save(hist_loss_filename, hist.history['loss'])
      print("File prediction loss saved {}".format(os.path.join(high_pred_path + hist_loss_filename)))
      #validation loss values
      hist_val_loss_filename = os.path.join(high_pred_path + pred_filename) + '_hist_val_loss'
      np.save(hist_val_loss_filename, hist.history['val_loss'])
      print("File prediction val_loss saved {}".format(os.path.join(high_pred_path + hist_val_loss_filename))) 
      #prediction
      np.save(os.path.join(high_pred_path + pred_filename), pred)
      print("File prediction saved {}".format(os.path.join(high_pred_path + pred_filename)))
# Out:
# -------------------------------------------
# Batch size:  16
# seq_lenght:  256
# Prediction for batch size 16 and seq lenght 256 with squared filters already done
# -------------------------------------------
# Batch size:  8
# seq_lenght:  256
# Prediction for batch size 8 and seq lenght 256 with squared filters already done
# -------------------------------------------
# Batch size:  4
# seq_lenght:  256
# Prediction for batch size 4 and seq lenght 256 with squared filters already done
# -------------------------------------------
# Batch size:  16
# seq_lenght:  126
# Prediction for batch size 16 and seq lenght 126 with squared filters already done
# -------------------------------------------
# Batch size:  8
# seq_lenght:  126
# Prediction for batch size 8 and seq lenght 126 with squared filters already done
# -------------------------------------------
# Batch size:  4
# seq_lenght:  126
# Prediction for batch size 4 and seq lenght 126 with squared filters already done
# -------------------------------------------
# Batch size:  16
# seq_lenght:  64
# Prediction for batch size 16 and seq lenght 64 with squared filters already done
# -------------------------------------------
# Batch size:  8
# seq_lenght:  64
# Prediction for batch size 8 and seq lenght 64 with squared filters already done
# -------------------------------------------
# Batch size:  4
# seq_lenght:  64
# Prediction for batch size 4 and seq lenght 64 with squared filters already done

# %% [markdown]
# ## Evaluation high CRNN arhitecture
#
# Evaluation in terms of F1-score and accuracy

# %%
#we retrieve all the information from the files and plot the results in terms of accuracy and F1_score
import matplotlib.pyplot as plt


for filename in os.listdir(high_pred_path):
  if (filename.split('.')[0].split('_')[-1]) != 'loss': 
    print('----------------------------------------')
    tmp_pred = np.load(os.path.join(high_pred_path, filename))
    hist_path_loss = filename.split('.')[0] + '_hist_loss.npy'
    hist_path_val_loss = filename.split('.')[0] + '_hist_val_loss.npy'
    pred_path = filename.split('.')[0] + '_lab.npy'
    tmp_hist_loss = np.load(os.path.join(high_pred_path, hist_path_loss))
    tmp_hist_val_loss = np.load(os.path.join(high_pred_path, hist_path_val_loss))
    #tresholding
    tmp_pred_re = reshape_3Dto2D(tmp_pred) > 0.7
    sed_gt = np.load(os.path.join(high_pred_lab_path, pred_path))
    
    print("Prediction for batch size: {}, sequence lenght: {}".format(filename.split('_')[1], filename.split('_')[2].split('.')[0]))

    accuracy = accuracy_score(sed_gt, tmp_pred_re)
    print("Accuracy: ", accuracy)

    f1 = f1_score(sed_gt, tmp_pred_re, zero_division=1)
    print("F1: ", f1)


    # summarize history for loss
    plt.plot(tmp_hist_loss)
    plt.plot(tmp_hist_val_loss)
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()
# Out:
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 256
# Accuracy:  0.9863093449519231
# F1:  0.0
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 256
# Accuracy:  0.9889197716346154
# F1:  0.0067340067340067354
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 256
# Accuracy:  0.9883000300480769
# F1:  0.0
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 126
# Accuracy:  0.9899648962148963
# F1:  0.0037878787878787876
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 126
# Accuracy:  0.989068583408206
# F1:  0.0
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 126
# Accuracy:  0.9863892597537457
# F1:  0.06852791878172589
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 64
# Accuracy:  0.9856896033653846
# F1:  0.005221932114882507
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 64
# Accuracy:  0.9866815476190476
# F1:  0.019178082191780823
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 64
# Accuracy:  0.9841343305687204
# F1:  0.09694415173867228

# %%
#we retrieve all the information from the files and plot the confusion matrices
import matplotlib.pyplot as plt


for filename in os.listdir(high_pred_path):
  if (filename.split('.')[0].split('_')[-1]) != 'loss': 
    print('----------------------------------------')
    tmp_pred = np.load(os.path.join(high_pred_path, filename))
    hist_path_loss = filename.split('.')[0] + '_hist_loss.npy'
    hist_path_val_loss = filename.split('.')[0] + '_hist_val_loss.npy'
    pred_path = filename.split('.')[0] + '_lab.npy'
    tmp_hist_loss = np.load(os.path.join(high_pred_path, hist_path_loss))
    tmp_hist_val_loss = np.load(os.path.join(high_pred_path, hist_path_val_loss))
    #tresholding
    tmp_pred_re = reshape_3Dto2D(tmp_pred) > 0.7
    sed_gt = np.load(os.path.join(high_pred_lab_path, pred_path))
  

    print("Prediction for batch size: {}, sequence lenght: {}".format(filename.split('_')[1], filename.split('_')[2].split('.')[0]))


    matrix_test = confusion_matrix(sed_gt, tmp_pred_re)
    print(matrix_test) 

    matrix_test_norm = confusion_matrix(sed_gt, tmp_pred_re, normalize='true') * 100 

    ax = sns.heatmap(matrix_test_norm, linewidth=0.5, annot=True, cmap="Blues", xticklabels= ['no onset', 'onset'], yticklabels= ['no onset','onset'])
    plt.show()
# Out:
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 256
# [[52519    25]
#  [  704     0]]
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 256
# [[52656    64]
#  [  526     2]]
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 256
# [[52625    23]
#  [  600     0]]
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 126
# [[51889    47]
#  [  479     1]]
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 126
# [[52840     8]
#  [  576     0]]
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 126
# [[53167   177]
#  [  557    27]]
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 64
# [[52484    76]
#  [  686     2]]
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 64
# [[53037   107]
#  [  609     7]]
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 64
# [[53113   271]
#  [  586    46]]

# %% [markdown]
# ## Wide CRNN architecture, kernel filter size 6X2

# %%
wide_pred_path = prediction_folder + 'wide_pred'
wide_pred_lab_path = label_for_prediction_folder + 'wide_pred_lab'
create_folder(wide_pred_path)
create_folder(wide_pred_lab_path)

# %%
from numpy.random import seed
seed(1)
import tensorflow as ts
from tensorflow.keras.layers import Bidirectional, Conv2D, MaxPool2D, Input, MaxPooling3D, Conv3D
from tensorflow.keras.layers import Dense, Activation, Dropout, Reshape, Permute
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.optimizers import Adam

ts.keras.backend.set_image_data_format('channels_last')

def get_model_wide(data_in, data_out, dropout_rate, nb_cnn2d_filt, pool_size,
              rnn_size, fnn_size, weights, first):

    #initial dimenison set for channel last
    spec_start = Input(shape=(data_in[2], data_in[3], data_in[1]))
    #dimension for cnn same as the starting point
    spec_cnn = spec_start
    for i, convCount in enumerate(pool_size):
        #convolutional layer - wide filkter size
        spec_cnn = Conv2D(filters=nb_cnn2d_filt, kernel_size=(2, 6), padding='same')(spec_cnn)
        spec_cnn = BatchNormalization(trainable=True)(spec_cnn, training=True)
        spec_cnn = Activation('relu')(spec_cnn)
        spec_cnn = MaxPool2D(pool_size=(1, pool_size[i]))(spec_cnn)

    #reshape to a proper dimension for recurrent layers
    spec_rnn = Reshape((data_in[2], 2*nb_cnn2d_filt))(spec_cnn)

    for nb_rnn_filt in rnn_size:
        spec_rnn = Bidirectional(
            GRU(nb_rnn_filt, activation='tanh', dropout=dropout_rate, recurrent_dropout=dropout_rate,
                return_sequences=True, reset_after=False), 
            merge_mode='mul'
        )(spec_rnn, training=True)

    #FC
    sed = spec_rnn
    sed = TimeDistributed(Dense(fnn_size[0]))(sed)
    sed = TimeDistributed(Dense(data_out[-1]))(sed)
    sed = Activation('sigmoid', name='sed_out')(sed)

    model = Model(inputs=spec_start, outputs=[sed])
    model.compile(optimizer=Adam(), loss=['binary_crossentropy'], loss_weights=weights)

    if first:
      model.summary()
    return model

# %%
import numpy as np
from numpy.random import seed
seed(1)
import sys
import os
import time
import matplotlib.pyplot as plot
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# get all the parameters i need for the project
nb_epochs = 25 #if changed all the prediction need to be re-done so please delete the file inside the folders and start the code again. 
first = 1


#loop trough the different epochs, sequence lenghth and batch size:
for seq_lenght in [256, 126, 64]:
  for batch_size in [16, 8, 4]:
    
    params['sequence_length'] = seq_lenght
    params['batch_size'] = batch_size
    params['nb_epochs'] = nb_epochs
    
    print('-------------------------------------------')
    
    print("Batch size: ", batch_size)
    print("seq_lenght: ", seq_lenght)
    pred_filename = '/pred_{}_{}'.format(batch_size, seq_lenght) 
    if os.path.exists(os.path.join(wide_pred_path + pred_filename + '.npy')):
      print("Prediction for batch size {0} and seq lenght {1} with squared filters already done".format(batch_size, seq_lenght))
    else:

      print("Path to file: ", os.path.join(wide_pred_path + pred_filename))

      data_gen_train = DataGenerator(
          nfft=params['nfft'],
          batch_size=params['batch_size'], seq_len=params['sequence_length'], datagen_mode='train'
      )


    # generation of testing dataset
      data_gen_test = DataGenerator(
         nfft=params['nfft'],
         batch_size=params['batch_size'], seq_len=params['sequence_length'], datagen_mode='test', shuffle=False
      )

      data_in, data_out = data_gen_train.get_data_sizes()

      model = get_model_high(data_in=data_in, data_out=data_out, dropout_rate=params['dropout_rate'],
                  nb_cnn2d_filt=params['nb_cnn2d_filt'], pool_size=params['pool_size'],
                  rnn_size=params['rnn_size'], fnn_size=params['fnn_size'],
                  weights=params['loss_weights'], first=first)
    
      #so we do print the model only for the first case 
      first = 0

      gt = collect_test_labels(data_gen_test, data_out, params['quick_test'])
      #reshape to 2D
      sed_gt = reshape_3Dto2D(gt)
      file_path = os.path.join(wide_pred_lab_path + pred_filename + '_lab')
      print("File prediction saved: {}".format(file_path))
      np.save(file_path, sed_gt)
      print("File prediction saved: {}".format(file_path))

     # it returns an history value
      #model fit
      hist = model.fit(
          x=data_gen_train.generate(),
          steps_per_epoch=1 if params['quick_test'] else data_gen_train.get_total_batches_in_data(),
          validation_data=data_gen_test.generate(),
          validation_steps=1 if params['quick_test'] else data_gen_test.get_total_batches_in_data(),
          epochs=nb_epochs,
          verbose=1)



      #model prediction
      pred = model.predict(
          x=data_gen_test.generate(),
          steps=1 if params['quick_test'] else data_gen_test.get_total_batches_in_data(),
          verbose=0
      )

    
      #training loss values
      hist_loss_filename = os.path.join(wide_pred_path + pred_filename) + '_hist_loss'
      np.save(hist_loss_filename, hist.history['loss'])
      print("File prediction loss saved {}".format(os.path.join(wide_pred_path + hist_loss_filename)))
      #validation loss values
      hist_val_loss_filename = os.path.join(wide_pred_path + pred_filename) + '_hist_val_loss'
      np.save(hist_val_loss_filename, hist.history['val_loss'])
      print("File prediction val_loss saved {}".format(os.path.join(wide_pred_path + hist_val_loss_filename)))
      #predictions 
      np.save(os.path.join(wide_pred_path + pred_filename), pred)
      print("File prediction saved {}".format(os.path.join(wide_pred_path + pred_filename)))
# Out:
# -------------------------------------------
# Batch size:  16
# seq_lenght:  256
# Prediction for batch size 16 and seq lenght 256 with squared filters already done
# -------------------------------------------
# Batch size:  8
# seq_lenght:  256
# Prediction for batch size 8 and seq lenght 256 with squared filters already done
# -------------------------------------------
# Batch size:  4
# seq_lenght:  256
# Prediction for batch size 4 and seq lenght 256 with squared filters already done
# -------------------------------------------
# Batch size:  16
# seq_lenght:  126
# Prediction for batch size 16 and seq lenght 126 with squared filters already done
# -------------------------------------------
# Batch size:  8
# seq_lenght:  126
# Prediction for batch size 8 and seq lenght 126 with squared filters already done
# -------------------------------------------
# Batch size:  4
# seq_lenght:  126
# Prediction for batch size 4 and seq lenght 126 with squared filters already done
# -------------------------------------------
# Batch size:  16
# seq_lenght:  64
# Prediction for batch size 16 and seq lenght 64 with squared filters already done
# -------------------------------------------
# Batch size:  8
# seq_lenght:  64
# Prediction for batch size 8 and seq lenght 64 with squared filters already done
# -------------------------------------------
# Batch size:  4
# seq_lenght:  64
# Prediction for batch size 4 and seq lenght 64 with squared filters already done

# %% [markdown]
# ## Evaluation CRNN wide architecture
#
# Evaluation in terms of accuracy and F1-score

# %%
#we retrieve all the information from the files and print them in terms of accuracy and F1-score
import matplotlib.pyplot as plt


for filename in os.listdir(wide_pred_path):
  if (filename.split('.')[0].split('_')[-1]) != 'loss': 
    print('----------------------------------------')
    tmp_pred = np.load(os.path.join(wide_pred_path, filename))
    hist_path_loss = filename.split('.')[0] + '_hist_loss.npy'
    hist_path_val_loss = filename.split('.')[0] + '_hist_val_loss.npy'
    pred_path = filename.split('.')[0] + '_lab.npy'
    tmp_hist_loss = np.load(os.path.join(wide_pred_path, hist_path_loss))
    tmp_hist_val_loss = np.load(os.path.join(wide_pred_path, hist_path_val_loss))
    #thresholding
    tmp_pred_re = reshape_3Dto2D(tmp_pred) > 0.7
    sed_gt = np.load(os.path.join(wide_pred_lab_path, pred_path))
    
    print("Prediction for batch size: {}, sequence lenght: {}".format(filename.split('_')[1], filename.split('_')[2].split('.')[0]))

    accuracy = accuracy_score(sed_gt, tmp_pred_re)
    print("Accuracy: ", accuracy)

    f1 = f1_score(sed_gt, tmp_pred_re, zero_division=1)
    print("F1: ", f1)

    # summarize history for loss
    plt.plot(tmp_hist_loss)
    plt.plot(tmp_hist_val_loss)
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()
# Out:
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 256
# Accuracy:  0.9862717848557693
# F1:  0.002728512960436562
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 256
# Accuracy:  0.9880558894230769
# F1:  0.015479876160990712
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 256
# Accuracy:  0.9877741887019231
# F1:  0.01809954751131222
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 64
# Accuracy:  0.9867788461538461
# F1:  0.0
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 126
# Accuracy:  0.9902319902319903
# F1:  0.0038910505836575876
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 64
# Accuracy:  0.9869605654761905
# F1:  0.022315202231520226
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 126
# Accuracy:  0.9863731656184487
# F1:  0.04712041884816754
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 64
# Accuracy:  0.9871149289099526
# F1:  0.03333333333333333
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 126
# Accuracy:  0.9868899273104881
# F1:  0.07822685788787483

# %%
#we retrieve all the information from the files and plot the confusion matrices
import matplotlib.pyplot as plt


for filename in os.listdir(wide_pred_path):
  if (filename.split('.')[0].split('_')[-1]) != 'loss': 
    print('----------------------------------------')
    tmp_pred = np.load(os.path.join(wide_pred_path, filename))
    hist_path_loss = filename.split('.')[0] + '_hist_loss.npy'
    hist_path_val_loss = filename.split('.')[0] + '_hist_val_loss.npy'
    pred_path = filename.split('.')[0] + '_lab.npy'
    tmp_hist_loss = np.load(os.path.join(wide_pred_path, hist_path_loss))
    tmp_hist_val_loss = np.load(os.path.join(wide_pred_path, hist_path_val_loss))
    #thresholding
    tmp_pred_re = reshape_3Dto2D(tmp_pred) > 0.7
    sed_gt = np.load(os.path.join(wide_pred_lab_path, pred_path))
    

    print("Prediction for batch size: {}, sequence lenght: {}".format(filename.split('_')[1], filename.split('_')[2].split('.')[0]))

    matrix_test = confusion_matrix(sed_gt, tmp_pred_re)
    print(matrix_test) 

    matrix_test_norm = confusion_matrix(sed_gt, tmp_pred_re, normalize='true') * 100 

    ax = sns.heatmap(matrix_test_norm, linewidth=0.5, annot=True, cmap="Blues", xticklabels= ['no onset', 'onset'], yticklabels= ['no onset','onset'])
    plt.show()
# Out:
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 256
# [[52516    28]
#  [  703     1]]
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 256
# [[52607   113]
#  [  523     5]]
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 256
# [[52591    57]
#  [  594     6]]
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 64
# [[52544    16]
#  [  688     0]]
# ----------------------------------------
# Prediction for batch size: 16, sequence lenght: 126
# [[51903    33]
#  [  479     1]]
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 64
# [[53051    93]
#  [  608     8]]
# ----------------------------------------
# Prediction for batch size: 8, sequence lenght: 126
# [[52678   170]
#  [  558    18]]
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 64
# [[53308    76]
#  [  620    12]]
# ----------------------------------------
# Prediction for batch size: 4, sequence lenght: 126
# [[53191   153]
#  [  554    30]]

# %% [markdown]
# Comment and discussion regarding the results can be found on the report: LINK TO REPORT
